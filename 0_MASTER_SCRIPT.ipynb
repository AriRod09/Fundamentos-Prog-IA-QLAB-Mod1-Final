# %%
# ==============================================================================
# PROYECTO: Gasto de Bolsillo en Salud en Perú (2020-2024)
# Autores: Katia Villalobos & Diego Linares | QLAB PUCP 2026
# ==============================================================================

# 1. INSTALACIÓN Y CARGA ÚNICA DE LIBRERÍAS
import os, zipfile, io, requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf  #
from google.colab import drive, auth
from pydrive2.auth import GoogleAuth
from pydrive2.drive import GoogleDrive
from oauth2client.client import GoogleCredentials

# 2. AUTENTICACIÓN CENTRALIZADA
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive_api = GoogleDrive(gauth)
drive.mount('/content/drive')

# 3. EJECUCIÓN SECUENCIAL
# Usamos la magia %run para ejecutar los notebooks como si fueran parte de este
print("Iniciando Carga y Limpieza...")
# %run "scripts/3_CARGA_LIMPIEZA.ipynb"

print("Iniciando Estadística Descriptiva...")
# %run "scripts/4_DESCRIPTIVAS.ipynb"

print("Iniciando Visualización...")
# %run "scripts/5_VISUALIZACION.ipynb"

print("Iniciando Análisis de Predicción y Causalidad...")
# %run "scripts/6_ANALISIS_PREDICTIVO.ipynb"
